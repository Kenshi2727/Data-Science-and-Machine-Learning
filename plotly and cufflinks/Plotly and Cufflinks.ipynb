# %%
import pandas as pd
import numpy as np

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 5.23.0

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)#connecting javascript to our notebook
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.34.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()#allows cufflinks to be used offline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.34.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df
# Out:
#            A         B         C         D
# 0   2.375718  1.620370 -1.359016 -0.765496
# 1  -0.277901  0.787906 -0.635951 -0.226987
# 2  -0.014332 -0.282999 -1.165366 -1.655911
# 3   0.864679  1.210191  0.164108  0.088567
# 4  -2.410231 -0.054369 -0.650288 -0.693547
# ..       ...       ...       ...       ...
# 95  0.451996 -0.532924 -0.091816 -0.239431
# 96 -0.288267 -1.187247  0.134736  0.133645
# 97  1.785335 -1.810507  0.980968 -0.678838
# 98 -0.087048 -0.529619 -0.394563 -0.554363
# 99  1.159764 -0.038667 -0.008226  1.398450
#
# [100 rows x 4 columns]

# %%
df2=pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.iplot() #plotly interactive image

# %%
df.iplot(kind='scatter',x='A',y='B') #scatter plot without markers

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers',size=20)

# %%
df2.iplot(kind='bar',x='Category',y='Values')

# %%
df
# Out:
#            A         B         C         D
# 0   2.375718  1.620370 -1.359016 -0.765496
# 1  -0.277901  0.787906 -0.635951 -0.226987
# 2  -0.014332 -0.282999 -1.165366 -1.655911
# 3   0.864679  1.210191  0.164108  0.088567
# 4  -2.410231 -0.054369 -0.650288 -0.693547
# ..       ...       ...       ...       ...
# 95  0.451996 -0.532924 -0.091816 -0.239431
# 96 -0.288267 -1.187247  0.134736  0.133645
# 97  1.785335 -1.810507  0.980968 -0.678838
# 98 -0.087048 -0.529619 -0.394563 -0.554363
# 99  1.159764 -0.038667 -0.008226  1.398450
#
# [100 rows x 4 columns]

# %%
df.iplot(kind='bar')#we get a bar for every single data point but that's not what we want!

# %%
# hence we can use some aggregate function like groupby etc. for better menaingful visulaization

# %%
df.sum().iplot(kind='bar') #sum for each column

# %%
df.iplot(kind='box')

# %%
df3=pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[500,400,300,200,100]})

# %%
df3
# Out:
#    x   y    z
# 0  1  10  500
# 1  2  20  400
# 2  3  30  300
# 3  4  20  200
# 4  5  10  100

# %%
df3.iplot(kind='surface')#this will create a 3D surface plot

# %%
df4=pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]}) #for visualizing in another way-*peak type

# %%
df4
# Out:
#    x   y  z
# 0  1  10  5
# 1  2  20  4
# 2  3  30  3
# 3  4  20  2
# 4  5  10  1

# %%
df4.iplot(kind='surface',colorscale='rdylbu')#rd for red yl for yellow and bu for blue

# %%
df['A'].iplot(kind='hist',bins=50)

# %%
df.iplot(kind='hist',bins=50)#when passing the entire dataframe we get an overlapping histogram

# %%
df[['A','B']]
# Out:
#            A         B
# 0   2.375718  1.620370
# 1  -0.277901  0.787906
# 2  -0.014332 -0.282999
# 3   0.864679  1.210191
# 4  -2.410231 -0.054369
# ..       ...       ...
# 95  0.451996 -0.532924
# 96 -0.288267 -1.187247
# 97  1.785335 -1.810507
# 98 -0.087048 -0.529619
# 99  1.159764 -0.038667
#
# [100 rows x 2 columns]

# %%
# Calculate the spread between columns A and B
df['Spread'] = df['A'] - df['B']
# Plot the spread
df['Spread'].iplot(kind='line', title='Spread between A and B')

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')

# %%
df.scatter_matrix()#ALL COLUMNS MUST BE NUMERICAL!
